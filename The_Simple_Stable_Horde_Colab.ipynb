# %% [markdown]
# <a href="https://colab.research.google.com/github/db0/Simple-AI-Horde-Colab/blob/main/The_Simple_Stable_Horde_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown #####Latest Update: 27-3-2023 11.35pm NZDST - Remove hf token, changed stats frequency to every 2 mins
#@markdown \
#@markdown ## Give your worker a name
#@markdown ##### (If you have used this before, please re-use your worker name)
# The horde url
horde_url = "https://stablehorde.net" 
worker_name = "Give your worker a cool name" #@param {type:"string"}

if worker_name == "" or worker_name == "Give me a cool worker name":
  print("Please enter a new worker name and resubmit")
#@markdown \
#@markdown ## Enter your API key for the horde
#@markdown ##### (If you havent got one, go to https://stablehorde.net/register)
api_key = "" #@param {type:"string"}

if api_key == "":
  print("Please enter an API key and resubmit")
#@markdown \


#@markdown ### Choose a mode
mode = "Simple" #@param ["Simple", "Pick My Model", "Inpainter", "Interrogation"]
    
#@markdown *Simple Mode = No input required, just click and go* \
#@markdown *Inpainting Mode = Runs the inpainter model and stable_diffusion (limited to 768x768, no post-processors)* \
#@markdown *Interrogation Mode = Fulfils requests for captions, tags and nsfw* \
#@markdown *Pick A Model Mode = Runs only the model selected below* 
#@markdown 


if mode == "Pick My Model":
    pick_my_model = "Counterfeit" #@param ["3DKX", "A to Zovya RPG", "Abyss OrangeMix", "AbyssOrangeMix-AfterDark", "ACertainThing", "AIO Pixel Art", "Analog Diffusion", "Anime Pencil Diffusion", "Anygen", "Anything Diffusion", "Anything v3", "App Icon Diffusion", "Arcane Diffusion", "Archer Diffusion", "Asim Simpsons", "Balloon Art", "Borderlands", "BPModel", "BubblyDubbly", "Char", "CharHelper", "Cheese Daddys Landscape Mix", "ChilloutMix", "ChromaV5", "Classic Animation Diffusion", "Clazy", "Colorful", "Coloring Book", "Comic-Diffusion", "Concept Sheet", "Counterfeit", "Cyberpunk Anime Diffusion", "CyriousMix", "Dan Mumford Style", "Dark Victorian Diffusion", "Darkest Diffusion", "Deliberate", "DGSpitzer Art Diffusion", "Disco Elysium", "DnD Item", "Double Exposure Diffusion", "Dreamlike Diffusion", "Dreamlike Photoreal", "DreamLikeSamKuvshinov", "Dreamshaper", "DucHaiten", "DucHaiten Classic Anime", "Dungeons and Diffusion", "Dungeons n Waifus", "Eimis Anime Diffusion", "Elden Ring Diffusion", "Elldreth's Lucid Mix", "Elldreths Retro Mix", "Epic Diffusion", "Eternos", "Experience", "ExpMix Line", "FaeTastic", "Fantasy Card Diffusion", "FKing SciFi", "Funko Diffusion", "Furry Epoch", "Future Diffusion", "Ghibli Diffusion", "GorynichMix", "Grapefruit Hentai", "Graphic-Art", "GTA5 Artwork Diffusion", "GuoFeng", "Guohua Diffusion", "HASDX", "Hassanblend", "Healy's Anime Blend", "Hentai Diffusion", "HRL", "iCoMix", "Illuminati Diffusion", "Inkpunk Diffusion", "Jim Eidomode", "JWST Deep Space Diffusion", "Kenshi", "Knollingcase", "Korestyle", "kurzgesagt", "Laolei New Berry Protogen Mix", "Lawlas's yiff mix", "Liberty", "Marvel Diffusion", "Mega Merge Diffusion", "Microcasing", "Microchars", "Microcritters", "Microscopic", "Microworlds", "Midjourney Diffusion", "Midjourney PaintArt", "Min Illust Background", "mo-di-diffusion", "ModernArt Diffusion", "Moedel", "MoistMix", "Movie Diffusion", "NeverEnding Dream", "Nitro Diffusion", "Openniji", "OrbAI", "Papercut Diffusion", "Papercutcraft", "Pastel Mix", "Perfect World", "PFG", "PIXHELL", "Poison", "Pokemon3D", "PortraitPlus", "PPP", "Pretty 2.5D", "PRMJ", "Project Unreal Engine 5", "ProtoGen", "Protogen Anime", "Protogen Infinity", "Pulp Vector Art", "PVC", "Rachel Walker Watercolors", "Rainbowpatch", "Ranma Diffusion", "RCNZ Dumb Monkey", "RCNZ Gorilla With A Brick", "RealBiter", "Realism Engine", "Realistic Vision", "Redshift Diffusion", "Rev Animated", "Robo-Diffusion", "Rodent Diffusion", "RPG", "Samdoesarts Ultmerge", "Sci-Fi Diffusion", "SD-Silicon", "Seek.art MEGA", "Smoke Diffusion", "Something", "Sonic Diffusion", "Spider-Verse Diffusion", "Squishmallow Diffusion", "Supermarionation", "Sygil-Dev Diffusion", "Synthwave", "SynthwavePunk", "T-Shirt Diffusion", "T-Shirt Print Designs", "TrexMix", "trinart", "Trinart Characters", "Tron Legacy Diffusion", "Uhmami", "Ultraskin", "UMI Olympus", "Unstable Ink Dream", "URPM", "Valorant Diffusion", "Van Gogh Diffusion", "Vector Art", "vectorartz", "Vintedois Diffusion", "VinteProtogenMix", "Vivid Watercolors", "Voxel Art Diffusion", "waifu_diffusion", "Wavyfusion", "Woop-Woop Photo", "Xynthii-Diffusion", "Yiffy", "Zack3D", "Zeipher Female Model", "Zelda BOTW"]

#@markdown \

#@markdown ### Show Logs
Show_Logs = True #@param {type:"boolean"}
#@markdown *If ticked, this will show a log in the output console for each generation.  If unticked, a flashing cursor will appear until an error occurs and the log is in the AI-Horde-Worker/logs folder* 

if mode == "Inpainter":
  allow_painting = True
  dynamic_models = False
  max_power = 18
  models_to_load = ["stable_diffusion", "stable_diffusion_inpainting"]
  models_to_skip = ["stable_diffusion_2.1",  "stable_diffusion_2.0"]
  allow_post_processing = False

elif mode == "Pick My Model":
  allow_painting = False
  dynamic_models = False
  max_power = 50
  models_to_load = [f"{pick_my_model}"]
  models_to_skip = ["stable_diffusion_2.1",  "stable_diffusion_2.0"]
  allow_post_processing = False

else:
  allow_painting = False
  dynamic_models = False
  max_power = 72
  models_to_load = ["Deliberate"]
  models_to_skip = ["stable_diffusion_inpainting", "stable_diffusion_2.1",  "stable_diffusion_2.0"]
  allow_post_processing = False

###  IGNORE FROM HERE UNLESS YOU KNOW WHAT YOU ARE DOING ###
priority_usernames = []
max_threads = 1
nsfw = True
censor_nsfw = False
blacklist = []
censorlist = []
allow_img2img = True
allow_controlnet = False
allow_unsafe_ip = True
number_of_dynamic_models = 1
max_models_to_download = 12
forms = ["caption","nsfw","interrogation","post-process"]

# %%
# %%time
#@markdown # Download and Install Stable Diffusion for Stable Horde
#@markdown This takes less than 5 minutes - please ignore any red errors telling you to restart the runtime after installing a new version of something
# !rm -rf /content/sample_data # this irritates me for no real reason...
# %cd /content

import os;
from IPython.display import clear_output
# !PIP_IGNORE_INSTALLED=0 pip install huggingface_hub
clear_output()

# this is faster than apt-get...
if not os.path.exists("/usr/bin/aria2c"):
  # !wget https://github.com/abcfy2/aria2-static-build/releases/download/continuous/aria2-x86_64-linux-musl_static.zip
  # !unzip aria2-x86_64-linux-musl_static.zip
  # !mv aria2c /usr/bin
  # !rm aria2-x86_64-linux-musl_static.zip

clear_output()

hf_repo_user="anonderpling" #@param {type:"string"}
hf_repo_name="horde_colab" #@param {type:"string"}
#@markdown - You should't need to change these unless you want to use a different repo for some reason.

# !mkdir -p /content/pip/wheels

def download_snapshots(): # I haven't tested this function, I cbf. the path is probably wrong. 
  # !mkdir -p /content/pip
  # %cd /content/pip
  from huggingface_hub import snapshot_download
  snapshot_download(
    repo_id=hf_repo_user+"/"+hf_repo_name,
    cache_dir = "/content/hf_cache", # allow deleting cache
    local_dir = "/content/pip/wheels",
    ignore_patterns=["wheels/torch-2.0.0+cu118-cp310-cp310-linux_x86_64.whl"], # download with aria2c. I'm impatient.
    local_dir_use_symlinks=False # don't use symlinks, stupid system. I don't want to upload symlinks to HF...
  )
  # torch is 2gb, takes a couple minutes while to download. I'm impatient, we'll grab it with aria2c in <30s instead.
  from huggingface_hub import HfFileSystem as hffs
  fs=hffs()
  torchname=fs.glob('anonderpling/horde_colab/wheels/torch-*.whl',detail=False)[0].split("/")[3]
  # !cd /content/pip/wheels/wheels; (echo "https://huggingface.co/anonderpling/horde_colab/resolve/main/wheels/{torchname}";"echo "        out=/content/pip/wheels/wheels/{torchname}")|sponge|aria2c -x16 --split=16
 
  clear_output()

#def download_lfs():
#  !mkdir -p /content/pip/wheels
#  !apt install aria2
#  !git clone --depth=1 https://hf.co/$hf_repo_user/$hf_repo_name /content/pip/wheels

def upload_new_files():
  from huggingface_hub import HfApi
  from huggingface_hub import login
  login(hf_api_key)
  api = HfApi()
  inurl=api.upload_folder( # https://huggingface.co/docs/huggingface_hub/v0.14.1/en/package_reference/hf_api#huggingface_hub.HfApi.upload_folder
    folder_path="/content/pip/wheels",
    path_in_repo="wheels",
    repo_id=hf_repo_user+"/"+hf_repo_name,
    commit_message="Updating wheels via huggingface_hub",
    allow_patterns="*.whl" # only upload the wheel files...
  )
  print("Uploaded files. Check them out at "+inurl)  

# %cd /content/
# !git clone https://github.com/db0/AI-Horde-Worker.git --single-branch --branch=comfy
# %cd /content/AI-Horde-Worker
#if hf_api_key != "":
#  !mkdir -p /content/pip/wheels/wheels
#  !pip wheel -r requirements.txt --wheel-dir=/content/pip/wheels/wheels
#  !pip install -r requirements.txt --no-index --find-links /content/pip/wheels/wheels
#  upload_new_files()
#else:
if True:
  download_snapshots()
  # !pip install -r /content/AI-Horde-Worker/requirements.txt --no-index --find-links /content/pip/wheels/wheels

# !rm -rf /content/pip /content/hf_cache

# %%
#@markdown # Start Stable Horde worker
#@markdown For maximum runtime, leave this browser tab running and clear the logs every 15-30 mins by hitting the X in the top left corner of the logs (will appear when hovering over the three dots)
import os

# %cd /content/AI-Horde-Worker

# !rm -rf bridgeData.yaml

if "api_key" in locals():
  data = f"""horde_url = "{horde_url}"
worker_name = "{worker_name}"
api_key = "{api_key}"
priority_usernames = {priority_usernames}
max_power = {max_power}
max_threads = {max_threads}
queue_size = 1
nsfw = {nsfw}
censor_nsfw = {censor_nsfw}
blacklist = {blacklist}
censorlist = {censorlist}
allow_img2img = {allow_img2img}
allow_painting = {allow_painting}
allow_unsafe_ip = {allow_unsafe_ip}
dynamic_models = {dynamic_models}
number_of_dynamic_models = {number_of_dynamic_models}
max_models_to_download = {max_models_to_download}
models_to_load = {models_to_load}
models_to_skip = {models_to_skip}
allow_controlnet = False
allow_post_processing = {allow_post_processing}
forms = {forms}
stats_output_frequency = 120"""
  toExec = """text_file = open("bridgeData.py", "w+"); text_file.write(data); text_file.close()""" 
  exec(toExec)

data2 = f"""hf_username = "huggingface_username"
hf_password = "huggingface_token"
"""
toExec2 = """text_file = open("creds.py", "w+"); text_file.write(data2); text_file.close()""" 
exec(toExec2)

# !export LOW_VRAM_MODE=0
if mode == "Interrogation":
  if Show_Logs:
    # !python bridge_alchemy.py -y
  else:
    print ("Your worker has started and is running while the cursor below is flashing")
    # !python bridge_alchemy.py -y -q

else:
  if Show_Logs:
    # !python bridge_stable_diffusion.py -y --disable_voodoo #--disable-xformers
  else:
    print ("Your worker has started and is running while the cursor below is flashing")
    # !python bridge_stable_diffusion.py -y -q --disable_voodoo #--disable-xformers

# %%
#@markdown # xterm
# !PIP_IGNORE_INSTALLED=0 pip install colab_xterm huggingface_hub
# %load_ext colabxterm
from IPython.display import clear_output
clear_output()
# %xterm

# %%
# %%time
#@markdown #Build wheels for horde_colab and upload to HF
#@markdown This takes less than 5 minutes - please ignore any red errors telling you to restart the runtime after installing a new version of something
# !rm -rf /content/sample_data # this irritates me for no real reason...
# %cd /content

import os;
from IPython.display import clear_output
# !PIP_IGNORE_INSTALLED=0 pip install huggingface_hub
clear_output()

# !apt install nano aria2 libcairo2-dev libjpeg-dev libgif-dev htop
clear_output()

hf_repo_user="anonderpling" #@param {type:"string"}
hf_repo_name="horde_colab" #@param {type:"string"}
hf_api_key="" #@param {type:"string"}
#@markdown - You should't need to change these unless you want to use a different repo for some reason.

# !mkdir -p /content/pip/wheels

def download_snapshots(): # I haven't tested this function, I cbf. the path is probably wrong. 
  # !mkdir -p /content/pip
  # %cd /content/pip
  from huggingface_hub import snapshot_download
  snapshot_download(
    repo_id=hf_repo_user+"/"+hf_repo_name,
    cache_dir = "/content/hf_cache", # allow deleting cache
    local_dir = "/content/pip/wheels",
    ignore_patterns=["wheels/torch-2.0.0+cu118-cp310-cp310-linux_x86_64.whl"], # download with aria2c. I'm impatient.
    local_dir_use_symlinks=False # don't use symlinks, stupid system. I don't want to upload symlinks to HF...
  )
  # torch is 2gb, takes a couple minutes while to download. I'm impatient, we'll grab it with aria2c in <30s instead.
  from huggingface_hub import HfFileSystem as hffs
  fs=hffs()
  torchname=fs.glob('anonderpling/horde_colab/wheels/torch-*.whl',detail=False)[0].split("/")[3]
  # !cd /content/pip/wheels/wheels; (echo "https://huggingface.co/anonderpling/horde_colab/resolve/main/wheels/{torchname}";"echo "        out=/content/pip/wheels/wheels/{torchname}")|sponge|aria2c -x16 --split=16
 
  clear_output()

def download_lfs():
  # !mkdir -p /content/pip/wheels
  # !apt install aria2
  # !git clone --depth=1 https://hf.co/$hf_repo_user/$hf_repo_name /content/pip/wheels

def upload_new_files():
  from huggingface_hub import HfApi
  from huggingface_hub import login
  login(hf_api_key)
  api = HfApi()
  inurl=api.upload_folder( # https://huggingface.co/docs/huggingface_hub/v0.14.1/en/package_reference/hf_api#huggingface_hub.HfApi.upload_folder
    folder_path="/content/pip/wheels",
    path_in_repo="wheels",
    repo_id=hf_repo_user+"/"+hf_repo_name,
    commit_message="Updating wheels via huggingface_hub",
    allow_patterns="*.whl" # only upload the wheel files...
  )
  print("Uploaded files. Check them out at "+inurl)  

# %cd /content/
# !git clone https://github.com/db0/AI-Horde-Worker.git --single-branch --branch=comfy
# %cd /content/AI-Horde-Worker
# !mkdir -p /content/pip/wheels/wheels
# !pip wheel -r requirements.txt --wheel-dir=/content/pip/wheels/wheels
# !pip install -r requirements.txt --no-index --find-links /content/pip/wheels/wheels
upload_new_files()

# !rm -rf /content/pip /content/hf_cache
